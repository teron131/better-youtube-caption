# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
import os

load_dotenv()

llm = ChatOpenAI(
    model="openai/gpt-oss-120b",
    temperature=0,
    api_key=os.getenv("OPENROUTER_API_KEY"),
    base_url="https://openrouter.ai/api/v1",
    use_responses_api=True,
    reasoning={"effort": "minimal"},
    extra_body={
        "include_reasoning": False,
        "provider": {"sort": "throughput"},
    },  # OpenRouter params
)

response = llm.invoke("Hi")

# %%
from rich import print

print(response.content_blocks[-1]["text"])
# Out:
# Hello! How can I help you today?

# %%
import os
from typing import List, Optional

import requests
from dotenv import load_dotenv
from pydantic import BaseModel

load_dotenv()


class TranscriptSegment(BaseModel):
    text: str
    startMs: str
    endMs: str
    startTimeText: str


class Video(BaseModel):
    title: Optional[str] = None
    description: Optional[str] = None
    transcript: Optional[List[TranscriptSegment]] = None
    transcript_only_text: Optional[str] = None


def get_video_data(youtube_url: str) -> Video:
    """Get video data including transcript segments, title, and description."""
    api_key = os.getenv("SCRAPECREATORS_API_KEY")
    api_url = f"https://api.scrapecreators.com/v1/youtube/video?url={youtube_url}&get_transcript=true"
    headers = {"x-api-key": api_key}

    response = requests.get(api_url, headers=headers)
    response.raise_for_status()

    data = response.json()

    # Parse transcript segments
    transcript_segments = None
    if data.get("transcript") and isinstance(data["transcript"], list):
        transcript_segments = [
            TranscriptSegment(
                text=seg.get("text", ""),
                startMs=seg.get("startMs", ""),
                endMs=seg.get("endMs", ""),
                startTimeText=seg.get("startTimeText", ""),
            )
            for seg in data["transcript"]
        ]

    return Video(
        title=data.get("title"),
        description=data.get("description"),
        transcript=transcript_segments,
        transcript_only_text=data.get("transcript_only_text"),
    )


# Usage:
video_url = "https://www.youtube.com/watch?v=MaBasS6vJ18"

video = get_video_data(video_url)

print(f"Title: {video.title}\n")
print(f"Description: {video.description}\n")
print(f"Number of transcript segments: {len(video.transcript) if video.transcript else 0}\n")
print("=" * 80)
print("FULL ORIGINAL TRANSCRIPT:")
print("=" * 80)
if video.transcript:
    for seg in video.transcript:
        print(f"[{seg.startTimeText}] {seg.text}")
# Out:
# Title: Anduril's Luckey: Must Get Off the Chinese Supply Chain
#
# Description: Anduril Founder Palmer Luckey discusses the need for US reindustrialization as competition with China's supply chain ramps up. He joins Caroline Hyde and Ed Ludlow live from Anduril's headquarters.
# --------
# Like this video? Subscribe to Bloomberg Technology on YouTube:
#    / @bloombergtechnology
#
# Watch the latest full episodes of "Bloomberg Technology" with Caroline Hyde and Ed Ludlow here:
#    • Bloomberg Technology With Caroline Hyde an...
#
# Get the latest in tech from Silicon Valley and around the world here:
# https://www.bloomberg.com/technology
# Connect with us on...
# X:   / technology
# Facebook:   / bloombergtechnology
# Instagram:   / bloombergbusiness
#
# Follow Ed Ludlow on X here:   / edludlow
# Follow Caroline Hyde on X here:   / carolinehydetv
#
# Listen to the daily Bloomberg Technology podcast here:
# https://www.bloomberg.com/podcasts/se...
#
# More from Bloomberg Business
# Connect with us on...
# X:   / business
# Facebook:   / bloombergbusiness
# Instagram:   / bloombergbusiness
# LinkedIn:   / bloomberg-news
# TikTok:   / bloombergbusiness
#
# Number of transcript segments: 244
#
# ================================================================================
# FULL ORIGINAL TRANSCRIPT:
# ================================================================================
# [0:00] My assumption is that the president's
# true social post was scheduled for 8
# [0:03] a.m.
# Pacific, 11 a.m.
# [0:04] Eastern.
# We don't know, but it's very simple.
# [0:08] He had said that he intended to meet
# with me in two weeks time, now doesn't
# [0:12] see a reason to do so.
# He threatened to massively increase
# [0:15] tariffs on Chinese goods and says that
# China is becoming increasingly hostile.
# [0:20] When you and I met in January, you
# opened our entire conversation with a
# [0:24] forecast of where you felt the
# relationship between us and China was
# [0:27] going.
# Yeah, we.
# [0:29] Right?
# Yeah, I think so.
# [0:30] I mean, the reality is that our
# interests are relatively divergent at
# [0:35] this point.
# And that's particularly true when it
# [0:37] comes to semiconductors, when it comes
# to Taiwan.
# [0:40] And so.
# TRUMP You know, I think what he's doing
# [0:42] right now is, is he's putting the art of
# the deal.
# [0:46] He's trying to get the best deal that he
# can.
# [0:48] And I, I understand that he has to
# manage he has to manage this reality
# [0:53] that right now we are kind of dependent
# on China for a lot of things.
# [0:57] But, you know, I think what we talked
# about last time is this is why we need
# [1:01] to re industrialize.
# This is why we need to have our own rare
# [1:03] earth supplies, is why we need to be
# able to make our own chips and our own
# [1:06] computers and our own products
# downstream because it takes away
# [1:08] leverage from China.
# They do have a lot of leverage right
# [1:12] now, and so it's very hard to make deals
# with them.
# [1:15] I think it's actually healthy for the
# US-China relationship for it to not be
# [1:21] so dependent on China right now.
# We don't have great solutions to
# [1:25] quantify it.
# I mean, so you're so involved in Arsenal
# [1:27] one, we will talk about that.
# But right now, the weapons that Andrew
# [1:31] makes and the autonomous systems, how
# dependent is that specific supply chain
# [1:36] at this moment on China?
# Andrew has done a uniquely good job of
# [1:39] getting away from China versus not just
# other defense companies, but also
# [1:43] compared to most American companies in
# general.
# [1:45] Remember that we are sanctioned by
# China.
# [1:48] Remember that our executives are
# personally sanctioned by China.
# [1:52] And so we have
# we can't we're not doing this for you to
# [1:56] leverage or negotiating reasons.
# We have to get off of Chinese supply
# [2:00] chain and not just things that are
# literally made in China, but even things
# [2:03] that are dependent on China.
# So it's dependent on Chinese precursor
# [2:07] chemicals or Chinese equipment or
# machinery or processing.
# [2:11] We have to make very aggressive moves to
# stay away from that and keep us and
# [2:16] allied supply chain to the absolute
# greatest extent possible.
# [2:19] So I would say Andrew is not even really
# what I'm concerned about.
# [2:23] It's the broader economy and maybe some
# other defense companies, if you can
# [2:27] believe it, there's lots of us defense
# companies that haven't been sanctioned
# [2:30] by China and therefore they haven't had
# the foresight to go and build it.
# [2:36] And as you are in Ohio, how is that
# going?
# [2:39] How is Arsenal managing to hit the
# milestones you want to see?
# [2:42] So Arsenal is not just important, but
# it's necessary.
# [2:45] So you guys know it's about 5 million
# square feet of manufacturing capacity
# [2:48] we're building in Ohio.
# We have to build it.
# [2:50] We have so much volume that we just have
# to output that we can't do it without
# [2:54] that new site.
# We started building that site many
# [2:58] months before the government gave us
# these contracts that we that are now
# [3:02] going to fulfill its capacity.
# And thank goodness we did like this
# [3:05] year, our production is up 400% over
# last year.
# [3:09] I'm sorry, as in non arsenal.
# What I'm saying not our non arsenal
# [3:14] production is up 400% and then so next
# year we expect to see an equally large
# [3:19] bump up and that is going to be critical
# for Arsenal to come online.
# [3:22] We actually already have the first round
# of employees who are going to be working
# [3:25] at Arsenal.
# We brought them from Ohio to HQ.
# [3:28] They're going to be here for the next
# six months.
# [3:31] I guess it's it's less than six months
# now.
# [3:32] They've been here for a while and that
# way they're able to get indoctrinated
# [3:36] and our processes work on our existing
# manufacturing systems.
# [3:39] And then when Arsenal one opens next
# year, they can go in and hit the ground
# [3:43] running.
# Day one.
# [3:44] What do you need from the Department of
# War?
# [3:46] What do I need for the Department of
# war?
# [3:48] I'm getting a lot of the support that I
# need to make across the Navy, in the
# [3:51] Army, in the Air Force.
# There is a recognition that we don't
# [3:54] have time as a country for business as
# usual, that we need to move much faster,
# [3:58] that we need to be building new things
# and new ways that we need to design
# [4:01] weapons that can be manufactured by the
# industrial base.
# [4:04] We have the talent base that we have.
# We haven't got that talent.
# [4:07] The oh, the country has the talent in
# spades.
# [4:09] They're just working on the wrong
# things.
# [4:11] Most of our best talent, you know,
# contrast this with the Cold War, is no
# [4:14] longer working on national security
# problems, but is working on things like
# [4:17] advertising optimization, on new apps,
# on on tools of entertainment rather than
# [4:21] tools of deterrence.
# And I've seen that reversing.
# [4:24] There's a lot of people and I'm of all
# ages we're talking to people who've been
# [4:28] in the industry for 20, 30 years, all
# the way down to kids who are just going
# [4:31] into school, learning disciplines that
# are relevant to aerospace and defense.
# [4:35] I think that there's a lot of people who
# are realizing we've been resting on our
# [4:38] laurels and coasting for a couple of
# decades, and then our tech industry has
# [4:41] to get in gear and work on more
# important problems.
# [4:44] There was a report about the NGC two
# system it named both Android and
# [4:51] Palantir.
# We've asked Palantir through Shon to
# [4:53] comment on that, but the report
# imbalances case move markets.
# [4:59] Could you just.
# Respond to that reporting which came
# [5:01] from Reuters and explain the sort of
# timeline and the inaccuracies that you
# [5:08] feel there are in that report.
# So you may or may not remember this, but
# [5:11] I was a journalism major myself.
# I was only a semester and a half away
# [5:15] from graduating.
# I was the online editor of the Daily 40
# [5:17] Niner, which was the Cal State Long
# Beach student run newspaper.
# [5:21] So I care a lot about this stuff, both
# as a internal perspective and then also
# [5:24] just from a journalist perspective.
# The journalist who wrote that Reuters
# [5:27] story would have been failed out of the
# class by any of my professors.
# [5:30] He refused to include our on the record
# statement.
# [5:33] He refused to include the on the record
# statement from the Army because they
# [5:35] fundamentally made the whole story, not
# a story.
# [5:39] There was an analysis saying, hey,
# there's all of these security problems
# [5:41] like the system, the prototype for NGC
# two next generation command control.
# [5:45] It's not tracking what the users are
# doing.
# [5:47] It doesn't have any passwords to log in.
# There's no security turned on.
# [5:51] And they said, oh, my God, this is a
# huge problem.
# [5:53] And we said, Guys, this was an early
# prototype.
# [5:55] The Army wasn't paying us to demonstrate
# user accounts.
# [5:58] It was paying us to demonstrate
# integration of different sensors,
# [6:01] different weapons systems all into one
# pipeline.
# [6:04] And Lattice has all this functionality.
# We do this all the time.
# [6:07] It's not like it's not like we don't
# know how to do this.
# [6:10] And the army said the same.
# They said, Yeah, we just turned on all
# [6:12] those features with just a few weeks
# later, all these issues that you're
# [6:15] talking about didn't exist.
# This was an internal security audit,
# [6:19] just noting that these things were a
# factor in that early prototype.
# [6:23] Yes.
# There's no access control.
# [6:25] Yes, that is a risk.
# Yes.
# [6:26] We have not audited all of their
# security, you know, all their security
# [6:29] code.
# That is a risk.
# [6:30] But that's completely normal for early,
# early development.
# [6:33] But Reuters didn't include our quote,
# didn't include the Army's quote, because
# [6:35] that would have made the entire story
# around it.
# [6:37] So instead, they include, quote,
# exclusively from our competitors and
# [6:40] from so-called anonymous sources saying
# that Android and Palantir are running
# [6:44] this fundamentally insecure thing, 99%
# chance that was planted by one of our
# [6:48] competitors who had access to that memo.
# And there's only a few people who could
# [6:51] have done it.
# And I can make people look bad by
# [6:53] slicing and dicing memos to I'll show
# you if I want.
# [6:55] I'll get back into the journalism game.
# We can say pretty definitively we've
# [6:59] given you the opportunity to comment on
# that.
# [7:01] You absolutely have.
# But I'm using this opportunity to attack
# [7:04] my editor.
# You just mentioned your your
# [7:06] competitors, let's call them legacy
# primes.
# [7:08] Right before you came to set, I read the
# data piece about still the dominance of
# [7:13] those companies in proportionately war
# contracts that Department of War
# [7:18] contracts are getting versus.
# Andrew They're still getting them.
# [7:21] PALMER Look, you so I remember I did not
# say that it was necessarily a prime who
# [7:25] planted.
# There's a lot of people who are
# [7:26] competing.
# I think there are like 40 companies
# [7:28] competing for NGC two.
# I'm not saying that it is it.
# [7:30] I'm just not saying that.
# I didn't say that it is.
# [7:33] Look, these guys are still winning a lot
# of contracts.
# [7:36] The reality, whether we like it or not,
# is that these companies do have a lot of
# [7:39] important weapons capability.
# We don't want them to go out of
# [7:41] business.
# We don't want them to fall over animals
# [7:43] working with a lot of them.
# I mean, that's that's my bias here.
# [7:46] I mean, we're working with Raytheon,
# we're working with Lockheed, we're
# [7:48] working with Northrop.
# We're also competing with them for
# [7:50] programs.
# I think that in general, the industry
# [7:53] needs to move towards a model where
# companies invest more of their own money
# [7:56] in these products, where they fail that
# need they need to skin their own knees,
# [8:00] not the needs of taxpayers.
# And companies disagree as to the extent
# [8:03] of whether that should be true.
# I think companies like and or all in the
# [8:07] short term and the long run are going to
# do much better, especially because the
# [8:11] services want to see more companies
# acting like general.
# [8:13] They want us to have more skin in the
# game.
# [8:15] They want everybody to have more skin in
# the game.
# [8:17] They know that it incentivizes the right
# kind of behavior is skin in the game.
# [8:20] There are a lot of retail investors, a
# lot of institutional investors who want
# [8:24] more access to be able to skin their
# knees when you slip up, but also benefit
# [8:29] from your growth.
# When are you going to IPO?
# [8:31] So it's going to be in the next few
# years.
# [8:32] And we've talked about this before, but
# I actually but it's still the number one
# [8:35] question we get for you.
# It is.
# [8:37] It just is.
# So, look, we are we we are on a path to
# [8:42] IPO.
# Like like I can explicitly say that I'm
# [8:44] not going to be coy about that.
# We are running the company as if we are
# [8:48] going to be audited by the other the
# auditors that are looking at a public
# [8:53] company, trading companies.
# We're running the company's financials
# [8:55] as if we need to be accountable to
# public market investors.
# [8:57] You need to be a certain shape of
# company to be in the public markets.
# [9:01] You need to have a certain level of
# credibility in your accounting process
# [9:04] across the organization.
# So like the old school and roll stuff
# [9:07] up, you know, toss it and toss it in the
# bin.
# [9:10] No need to do any paperwork.
# No, You actually have to properly
# [9:12] account for what's on the shelf, what
# you've thrown away, what's working.
# [9:16] And we've gotten into that swing of
# things.
# [9:18] It's going to be it's going to be it's
# going to be in low single digit years.
# [9:22] And by the way, you have to be
# profitable for that.
# [9:24] Like at the moment, it is very expensive
# what you are trying to build.
# [9:28] Agreed.
# So my philosophy on this is that if you
# [9:31] are going to be in the public markets,
# you need to be the shape the markets
# [9:34] want you to be.
# I think that's not a very unprofitable
# [9:37] company that has a trend that looks very
# unprofitable.
# [9:40] So my personal opinion and I'm not
# hiding the data from you, we genuinely
# [9:43] don't know.
# We're not going to do it till the right
# [9:44] moment.
# We don't have to.
# [9:45] Private capital is amply available to
# us, but what we want to do is either be
# [9:51] profitable across the business or we
# want to be on very close to it with a
# [9:56] clear trend showing.
# It's certainly going to happen.
# [9:59] And I don't mean it's.
# It happened 70 years in the future.
# [10:01] I mean, like, hey, we have these
# contracts.
# [10:03] And if you just believe that we are
# going to deliver the things that we've
# [10:07] already sold, then you know that we're
# likely going to be profitable.
# [10:10] I'd like to talk about some of the
# weapons and autonomous systems that are
# [10:14] behind us, if we can.
# You have both relationships with the US
# [10:20] government and defense apparatus, but
# Western allies, too.
# [10:23] That's right.
# Are these prototypes or do we see
# [10:26] militaries around the world deploying
# them?
# [10:28] Are they real?
# There are going to be loads of people
# [10:30] watching this show that actually don't
# know and drill.
# [10:32] But also many skeptics say, like, you
# know, this, these are prototypes and
# [10:36] this is a startup in its infancy.
# Well, if we do our job correctly and we
# [10:40] stop some of these major wars from
# starting, then people are going to
# [10:42] continue to be unfamiliar with and all
# that, that the bizarre nature of our job
# [10:46] and also the job of our military, is
# that a better job we do of not having a
# [10:49] fight, the easier it is for people to
# either not pay attention to us or in
# [10:52] fact say, well, those guys are useless.
# We don't need them.
# [10:55] It's only when everything goes to that.
# Everyone talks about how great the
# [10:58] millions are.
# I'm going to jump in and apologize for
# [11:01] the choice language to our audience
# because it's quite early here and I'm so
# [11:04] I'm so sorry.
# It's okay.
# [11:06] I'm a young guy and I've got really bad.
# I'm not.
# [11:09] I'm not.
# I'm not.
# [11:09] I'm not I don't have, like, that English
# posh type of, you know, version.
# [11:13] Yes.
# We accept the apology.
# [11:16] Same question.
# All these systems deployed in the real
# [11:19] world by nations in case they need to
# use them.
# [11:22] So many of these systems are for
# example, Altice has been in Ukraine
# [11:26] since early in the war.
# We've also shipped a lot of these to
# [11:28] nations that are really, I think, on the
# precipice of conflict, like Taiwan.
# [11:32] Others of these, I think, have not been
# deployed by anyone but the United
# [11:35] States.
# You know, Roadrunner has been deployed
# [11:37] by the United States, but there are
# other people in other allied nations who
# [11:40] are very interested.
# Same thing with fury.
# [11:42] We've already delivered the first furies
# to the United States Air Force.
# [11:45] But there's a lot of interest in Korea,
# in Japan, in a variety of European
# [11:50] nations, Australia.
# These are nations that are strongly
# [11:53] allied with the United States and they
# want to have commonality.
# [11:55] Think of it this way Everyone who's
# buying F-35s is bought into the US plan
# [12:00] of how we're going to fight and deter
# these wars.
# [12:02] Something like Fury that tightly
# integrates with an F-35 is of a lot of
# [12:06] interest to them, especially if it means
# they don't have to develop it all
# [12:09] themselves, and especially if we're
# willing to manufacture it in their
# [12:13] country, which we are.
# I think that we need to be having
# [12:15] manufacturing bases across all our
# allies.
# [12:17] One of the superpowers the US has that
# China does not is friends around the
# [12:21] world.
# China does not have friends around the
# [12:24] world.
# They've got a couple buddies who have to
# [12:26] suck up to them in their immediate local
# region, but they do not have people
# [12:30] across the planet who are willing to
# work with them to build the war machine
# [12:34] that we need to deter their aggression.
# We should be taking advantage of that,
# [12:37] not pulling back on it.

# %%
import os
import re
from typing import List

from dotenv import load_dotenv
from langchain_core.messages import HumanMessage, SystemMessage
from langchain_openai import ChatOpenAI

load_dotenv()

# Get API key
api_key = os.getenv("OPENROUTER_API_KEY")

llm = ChatOpenAI(
    model="x-ai/grok-code-fast-1",
    temperature=0,
    api_key=api_key,
    base_url="https://openrouter.ai/api/v1",
)


# Format transcript segments as simple newline-separated text
# Format: [timestamp] text (one segment per line)
def format_transcript_segments(segments: List[TranscriptSegment]) -> str:
    """Format transcript segments as newline-separated text.

    Removes internal newlines from each segment and joins with spaces,
    so each segment is exactly one line.
    """
    formatted_segments = []
    for seg in segments:
        # Remove internal newlines and normalize whitespace
        normalized_text = " ".join(seg.text.split())
        formatted_segments.append(f"[{seg.startTimeText}] {normalized_text}")
    return "\n".join(formatted_segments)


def parse_refined_transcript(refined_text: str, original_segments: List[TranscriptSegment]) -> List[TranscriptSegment]:
    """Parse refined transcript back into segments, preserving original timestamps.

    The refined text should have format: [timestamp] text (one segment per line).
    Each line represents one segment.
    """
    lines = refined_text.strip().split("\n")
    refined_segments = []

    for i, line in enumerate(lines):
        if i >= len(original_segments):
            break

        # Extract timestamp and text from line
        timestamp_match = re.match(r"\[([^\]]+)\]\s*(.*)", line)

        if timestamp_match:
            orig_seg = original_segments[i]
            refined_text_only = timestamp_match.group(2).strip()

            refined_segments.append(
                TranscriptSegment(
                    text=refined_text_only,
                    startMs=orig_seg.startMs,  # Preserve original timestamps
                    endMs=orig_seg.endMs,
                    startTimeText=orig_seg.startTimeText,
                )
            )
        else:
            # Fallback: use original segment if parsing fails
            orig_seg = original_segments[i]
            refined_segments.append(
                TranscriptSegment(
                    text=line.strip(),
                    startMs=orig_seg.startMs,
                    endMs=orig_seg.endMs,
                    startTimeText=orig_seg.startTimeText,
                )
            )

    return refined_segments


# Test with first 20 segments
num_test_segments = 20
test_segments = video.transcript[:num_test_segments] if video.transcript else []

# Format transcript as simple text (one segment per line)
transcript_text = format_transcript_segments(test_segments)

# System prompt with title and description context
system_prompt = f"""You are correcting a YouTube video transcript. Use the full contextual understanding to ground your corrections, especially for special terms.

Video Title: {video.title}
Video Description: {video.description}

CRITICAL CONSTRAINTS:
1. Only fix typos and grammar errors. Do NOT change the meaning or structure.
2. PRESERVE ALL NEWLINES - each line represents a separate transcript segment.
3. PRESERVE TIMESTAMPS - keep the [timestamp] format exactly as shown.
4. Do NOT merge lines together - keep the same number of lines.
5. Keep text length similar to original - don't make sentences too long or short.
6. If a sentence is broken across lines, keep it broken - only fix typos/grammar within each line."""

# User message with transcript
user_prompt = f"""Refine the following transcript by fixing typos and grammar errors. Preserve all newlines and timestamps exactly as shown.

Transcript:
{transcript_text}

Return the refined transcript with the same number of lines and timestamps preserved."""

messages = [
    SystemMessage(content=system_prompt),
    HumanMessage(content=user_prompt),
]

# Show original formatted transcript
print("=" * 80)
print("ORIGINAL FORMATTED TRANSCRIPT (sent to model):")
print("=" * 80)
print(transcript_text)
print("\n" + "=" * 80)

# Get refined text (simple string output)
refined_text = llm.invoke(messages).content

print("=" * 80)
print("FULL REFINED TRANSCRIPT (from model):")
print("=" * 80)
print(refined_text)
print("\n" + "=" * 80)

# Parse refined text back into segments
refined_segments = parse_refined_transcript(refined_text, test_segments)

print(f"\nParsed {len(refined_segments)} refined segments")
print("=" * 80)
print("PARSED REFINED SEGMENTS:")
print("=" * 80)
for i, seg in enumerate(refined_segments, 1):
    print(f"{i}. [{seg.startTimeText}] {seg.text}")
    print(f"   Timestamps: {seg.startMs}ms - {seg.endMs}ms")
# Out:
# ================================================================================
# ORIGINAL FORMATTED TRANSCRIPT (sent to model):
# ================================================================================
# [0:00] My assumption is that the president's true social post was scheduled for 8
# [0:03] a.m. Pacific, 11 a.m.
# [0:04] Eastern. We don't know, but it's very simple.
# [0:08] He had said that he intended to meet with me in two weeks time, now doesn't
# [0:12] see a reason to do so. He threatened to massively increase
# [0:15] tariffs on Chinese goods and says that China is becoming increasingly hostile.
# [0:20] When you and I met in January, you opened our entire conversation with a
# [0:24] forecast of where you felt the relationship between us and China was
# [0:27] going. Yeah, we.
# [0:29] Right? Yeah, I think so.
# [0:30] I mean, the reality is that our interests are relatively divergent at
# [0:35] this point. And that's particularly true when it
# [0:37] comes to semiconductors, when it comes to Taiwan.
# [0:40] And so. TRUMP You know, I think what he's doing
# [0:42] right now is, is he's putting the art of the deal.
# [0:46] He's trying to get the best deal that he can.
# [0:48] And I, I understand that he has to manage he has to manage this reality
# [0:53] that right now we are kind of dependent on China for a lot of things.
# [0:57] But, you know, I think what we talked about last time is this is why we need
# [1:01] to re industrialize. This is why we need to have our own rare
#
# ================================================================================
# ================================================================================
# FULL REFINED TRANSCRIPT (from model):
# ================================================================================
# [0:00] My assumption is that the president's Truth Social post was scheduled for 8
# [0:03] a.m. Pacific, 11 a.m.
# [0:04] Eastern. We don't know, but it's very simple.
# [0:08] He had said that he intended to meet with me in two weeks' time, now doesn't
# [0:12] see a reason to do so. He threatened to massively increase
# [0:15] tariffs on Chinese goods and says that China is becoming increasingly hostile.
# [0:20] When you and I met in January, you opened our entire conversation with a
# [0:24] forecast of where you felt the relationship between us and China was
# [0:27] going. Yeah, we.
# [0:29] Right? Yeah, I think so.
# [0:30] I mean, the reality is that our interests are relatively divergent at
# [0:35] this point. And that's particularly true when it
# [0:37] comes to semiconductors, when it comes to Taiwan.
# [0:40] And so. TRUMP You know, I think what he's doing
# [0:42] right now is, is he's putting the art of the deal.
# [0:46] He's trying to get the best deal that he can.
# [0:48] And I, I understand that he has to manage, he has to manage this reality
# [0:53] that right now we are kind of dependent on China for a lot of things.
# [0:57] But, you know, I think what we talked about last time is this is why we need
# [1:01] to reindustrialize. This is why we need to have our own rare
#
# ================================================================================
#
# Parsed 20 refined segments
# ================================================================================
# PARSED REFINED SEGMENTS:
# ================================================================================
# 1. [0:00] My assumption is that the president's Truth Social post was scheduled for 8
#    Timestamps: 60ms - 3070ms
# 2. [0:03] a.m. Pacific, 11 a.m.
#    Timestamps: 3070ms - 4170ms
# 3. [0:04] Eastern. We don't know, but it's very simple.
#    Timestamps: 4170ms - 8160ms
# 4. [0:08] He had said that he intended to meet with me in two weeks' time, now doesn't
#    Timestamps: 8520ms - 12630ms
# 5. [0:12] see a reason to do so. He threatened to massively increase
#    Timestamps: 12630ms - 15450ms
# 6. [0:15] tariffs on Chinese goods and says that China is becoming increasingly hostile.
#    Timestamps: 15450ms - 20040ms
# 7. [0:20] When you and I met in January, you opened our entire conversation with a
#    Timestamps: 20430ms - 24360ms
# 8. [0:24] forecast of where you felt the relationship between us and China was
#    Timestamps: 24540ms - 27900ms
# 9. [0:27] going. Yeah, we.
#    Timestamps: 27900ms - 29039ms
# 10. [0:29] Right? Yeah, I think so.
#    Timestamps: 29040ms - 30910ms
# 11. [0:30] I mean, the reality is that our interests are relatively divergent at
#    Timestamps: 30930ms - 35220ms
# 12. [0:35] this point. And that's particularly true when it
#    Timestamps: 35220ms - 37950ms
# 13. [0:37] comes to semiconductors, when it comes to Taiwan.
#    Timestamps: 37950ms - 40440ms
# 14. [0:40] And so. TRUMP You know, I think what he's doing
#    Timestamps: 40800ms - 42840ms
# 15. [0:42] right now is, is he's putting the art of the deal.
#    Timestamps: 42840ms - 46130ms
# 16. [0:46] He's trying to get the best deal that he can.
#    Timestamps: 46140ms - 48160ms
# 17. [0:48] And I, I understand that he has to manage, he has to manage this reality
#    Timestamps: 48510ms - 53609ms
# 18. [0:53] that right now we are kind of dependent on China for a lot of things.
#    Timestamps: 53610ms - 57180ms
# 19. [0:57] But, you know, I think what we talked about last time is this is why we need
#    Timestamps: 57750ms - 61110ms
# 20. [1:01] to reindustrialize. This is why we need to have our own rare
#    Timestamps: 61410ms - 63930ms

# %%
# Compare original vs refined segments to verify timestamp preservation
print("=" * 80)
print("TIMESTAMP PRESERVATION CHECK")
print("=" * 80)

if test_segments and refined_segments:
    num_to_compare = min(len(test_segments), len(refined_segments))

    timestamp_matches = []
    text_length_changes = []

    for i in range(num_to_compare):
        orig = test_segments[i]
        refined = refined_segments[i]

        # Check timestamp matches (should all match since we preserve them programmatically)
        startMs_match = orig.startMs == refined.startMs
        endMs_match = orig.endMs == refined.endMs
        startTimeText_match = orig.startTimeText == refined.startTimeText

        timestamp_match = startMs_match and endMs_match and startTimeText_match
        timestamp_matches.append(timestamp_match)

        text_changed = orig.text.strip() != refined.text.strip()
        length_diff = len(refined.text) - len(orig.text)
        text_length_changes.append(length_diff)

        # Show full comparison for all segments
        print(f"\nSegment {i+1}:")
        print(f"  Timestamps Match: {timestamp_match}")
        if not timestamp_match:
            print(f"    startMs: '{orig.startMs}' vs '{refined.startMs}' - Match: {startMs_match}")
            print(f"    endMs: '{orig.endMs}' vs '{refined.endMs}' - Match: {endMs_match}")
            print(f"    startTimeText: '{orig.startTimeText}' vs '{refined.startTimeText}' - Match: {startTimeText_match}")
        print(f"  Original: [{orig.startTimeText}] {orig.text}")
        print(f"  Refined:   [{refined.startTimeText}] {refined.text}")
        print(f"  Text Changed: {text_changed}")
        if text_changed:
            print(f"    Original length: {len(orig.text)} chars")
            print(f"    Refined length:  {len(refined.text)} chars")
            print(f"    Length diff:     {length_diff:+d} chars")

    print("\n" + "=" * 80)
    print("SUMMARY:")
    print(f"  Segments sent: {len(test_segments)}")
    print(f"  Segments received: {len(refined_segments)}")
    print(f"  Segments compared: {num_to_compare}")
    print(f"  Timestamps preserved: {sum(timestamp_matches)}/{len(timestamp_matches)}")
    print(f"  Segment count match: {len(test_segments) == len(refined_segments)}")
    if text_length_changes:
        avg_length_change = sum(text_length_changes) / len(text_length_changes)
        max_length_change = max(abs(d) for d in text_length_changes)
        print(f"  Avg length change: {avg_length_change:+.1f} chars")
        print(f"  Max length change: {max_length_change} chars")

    # Show line count comparison (should match)
    original_lines = len(transcript_text.split("\n"))
    refined_lines = len(refined_text.strip().split("\n"))
    print(f"  Original lines: {original_lines}")
    print(f"  Refined lines: {refined_lines}")
    print(f"  Line count match: {original_lines == refined_lines}")
else:
    print("No transcript segments to compare")
# Out:
# ================================================================================
# TIMESTAMP PRESERVATION CHECK
# ================================================================================
#
# Segment 1:
#   Timestamps Match: True
#   Original: [0:00] My assumption is that the president's
# true social post was scheduled for 8
#   Refined:   [0:00] My assumption is that the president's Truth Social post was scheduled for 8
#   Text Changed: True
#     Original length: 74 chars
#     Refined length:  75 chars
#     Length diff:     +1 chars
#
# Segment 2:
#   Timestamps Match: True
#   Original: [0:03] a.m.
# Pacific, 11 a.m.
#   Refined:   [0:03] a.m. Pacific, 11 a.m.
#   Text Changed: True
#     Original length: 21 chars
#     Refined length:  21 chars
#     Length diff:     +0 chars
#
# Segment 3:
#   Timestamps Match: True
#   Original: [0:04] Eastern.
# We don't know, but it's very simple.
#   Refined:   [0:04] Eastern. We don't know, but it's very simple.
#   Text Changed: True
#     Original length: 45 chars
#     Refined length:  45 chars
#     Length diff:     +0 chars
#
# Segment 4:
#   Timestamps Match: True
#   Original: [0:08] He had said that he intended to meet
# with me in two weeks time, now doesn't
#   Refined:   [0:08] He had said that he intended to meet with me in two weeks' time, now doesn't
#   Text Changed: True
#     Original length: 75 chars
#     Refined length:  76 chars
#     Length diff:     +1 chars
#
# Segment 5:
#   Timestamps Match: True
#   Original: [0:12] see a reason to do so.
# He threatened to massively increase
#   Refined:   [0:12] see a reason to do so. He threatened to massively increase
#   Text Changed: True
#     Original length: 58 chars
#     Refined length:  58 chars
#     Length diff:     +0 chars
#
# Segment 6:
#   Timestamps Match: True
#   Original: [0:15] tariffs on Chinese goods and says that
# China is becoming increasingly hostile.
#   Refined:   [0:15] tariffs on Chinese goods and says that China is becoming increasingly hostile.
#   Text Changed: True
#     Original length: 78 chars
#     Refined length:  78 chars
#     Length diff:     +0 chars
#
# Segment 7:
#   Timestamps Match: True
#   Original: [0:20] When you and I met in January, you
# opened our entire conversation with a
#   Refined:   [0:20] When you and I met in January, you opened our entire conversation with a
#   Text Changed: True
#     Original length: 72 chars
#     Refined length:  72 chars
#     Length diff:     +0 chars
#
# Segment 8:
#   Timestamps Match: True
#   Original: [0:24] forecast of where you felt the
# relationship between us and China was
#   Refined:   [0:24] forecast of where you felt the relationship between us and China was
#   Text Changed: True
#     Original length: 68 chars
#     Refined length:  68 chars
#     Length diff:     +0 chars
#
# Segment 9:
#   Timestamps Match: True
#   Original: [0:27] going.
# Yeah, we.
#   Refined:   [0:27] going. Yeah, we.
#   Text Changed: True
#     Original length: 16 chars
#     Refined length:  16 chars
#     Length diff:     +0 chars
#
# Segment 10:
#   Timestamps Match: True
#   Original: [0:29] Right?
# Yeah, I think so.
#   Refined:   [0:29] Right? Yeah, I think so.
#   Text Changed: True
#     Original length: 24 chars
#     Refined length:  24 chars
#     Length diff:     +0 chars
#
# Segment 11:
#   Timestamps Match: True
#   Original: [0:30] I mean, the reality is that our
# interests are relatively divergent at
#   Refined:   [0:30] I mean, the reality is that our interests are relatively divergent at
#   Text Changed: True
#     Original length: 69 chars
#     Refined length:  69 chars
#     Length diff:     +0 chars
#
# Segment 12:
#   Timestamps Match: True
#   Original: [0:35] this point.
# And that's particularly true when it
#   Refined:   [0:35] this point. And that's particularly true when it
#   Text Changed: True
#     Original length: 48 chars
#     Refined length:  48 chars
#     Length diff:     +0 chars
#
# Segment 13:
#   Timestamps Match: True
#   Original: [0:37] comes to semiconductors, when it comes
# to Taiwan.
#   Refined:   [0:37] comes to semiconductors, when it comes to Taiwan.
#   Text Changed: True
#     Original length: 49 chars
#     Refined length:  49 chars
#     Length diff:     +0 chars
#
# Segment 14:
#   Timestamps Match: True
#   Original: [0:40] And so.
# TRUMP You know, I think what he's doing
#   Refined:   [0:40] And so. TRUMP You know, I think what he's doing
#   Text Changed: True
#     Original length: 47 chars
#     Refined length:  47 chars
#     Length diff:     +0 chars
#
# Segment 15:
#   Timestamps Match: True
#   Original: [0:42] right now is, is he's putting the art of
# the deal.
#   Refined:   [0:42] right now is, is he's putting the art of the deal.
#   Text Changed: True
#     Original length: 50 chars
#     Refined length:  50 chars
#     Length diff:     +0 chars
#
# Segment 16:
#   Timestamps Match: True
#   Original: [0:46] He's trying to get the best deal that he
# can.
#   Refined:   [0:46] He's trying to get the best deal that he can.
#   Text Changed: True
#     Original length: 45 chars
#     Refined length:  45 chars
#     Length diff:     +0 chars
#
# Segment 17:
#   Timestamps Match: True
#   Original: [0:48] And I, I understand that he has to
# manage he has to manage this reality
#   Refined:   [0:48] And I, I understand that he has to manage, he has to manage this reality
#   Text Changed: True
#     Original length: 71 chars
#     Refined length:  72 chars
#     Length diff:     +1 chars
#
# Segment 18:
#   Timestamps Match: True
#   Original: [0:53] that right now we are kind of dependent
# on China for a lot of things.
#   Refined:   [0:53] that right now we are kind of dependent on China for a lot of things.
#   Text Changed: True
#     Original length: 69 chars
#     Refined length:  69 chars
#     Length diff:     +0 chars
#
# Segment 19:
#   Timestamps Match: True
#   Original: [0:57] But, you know, I think what we talked
# about last time is this is why we need
#   Refined:   [0:57] But, you know, I think what we talked about last time is this is why we need
#   Text Changed: True
#     Original length: 76 chars
#     Refined length:  76 chars
#     Length diff:     +0 chars
#
# Segment 20:
#   Timestamps Match: True
#   Original: [1:01] to re industrialize.
# This is why we need to have our own rare
#   Refined:   [1:01] to reindustrialize. This is why we need to have our own rare
#   Text Changed: True
#     Original length: 61 chars
#     Refined length:  60 chars
#     Length diff:     -1 chars
#
# ================================================================================
# SUMMARY:
#   Segments sent: 20
#   Segments received: 20
#   Segments compared: 20
#   Timestamps preserved: 20/20
#   Segment count match: True
#   Avg length change: +0.1 chars
#   Max length change: 1 chars
#   Original lines: 20
#   Refined lines: 20
#   Line count match: True
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
